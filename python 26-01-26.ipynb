# %% [markdown]
# ## Keep checking internet connection status until connected

# %%
status = ""
while status != "connected":
    status = input("Check Internet Connection :")
print("Connection Successfully")
# Out:
# Connection Successfully
