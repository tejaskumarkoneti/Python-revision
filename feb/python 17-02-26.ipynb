# %% [markdown]
# ### 41. Rotate Array Right by K
#
# **Question:**
# Rotate array elements to the right by K positions.
#
# **Sample Input:**
# Array: 1 2 3 4 5
# K = 2
#
# **Sample Output:**
# 4 5 1 2 3
#
# **Explanation:**
# Last K elements move to front.

# %% [markdown]
# ### 42. Find Frequency of Each Element
#
# **Question:**
# Count how many times each element appears in array.
#
# **Sample Input:**
# 1 2 2 3 3 3
#
# **Sample Output:**
# 1→1, 2→2, 3→3
#
# **Explanation:**
# Use dictionary or nested loop.

# %% [markdown]
# ### 43. Common Elements Between Two Arrays
#
# **Question:**
# Find common values from two arrays.
#
# **Sample Input:**
# A: 1 2 3 4
# B: 3 4 5 6
#
# **Sample Output:**
# 3 4
#
# **Explanation:**
# Compare elements and collect matches.

# %% [markdown]
# ### 44. Intersection of Arrays
#
# **Question:**
# Return intersection (unique common elements).
#
# **Sample Input:**
# A: 2 4 6 8
# B: 4 8 10
#
# **Sample Output:**
# 4 8
#
# **Explanation:**
# Only shared elements are returned.

# %% [markdown]
# ### 45. Union of Arrays
#
# **Question:**
# Combine two arrays without duplicates.
#
# **Sample Input:**
# A: 1 2 3
# B: 3 4 5
#
# **Sample Output:**
# 1 2 3 4 5
#
# **Explanation:**
# Merge and remove duplicates.

# %% [markdown]
# ### 46. Longest Word in String
#
# **Question:**
# Find the longest word in a sentence.
#
# **Sample Input:**
# I love logical programming
#
# **Sample Output:**
# programming
#
# **Explanation:**
# Compare word lengths.

# %% [markdown]
# ### 47. Count Words in a Sentence
#
# **Question:**
# Count total words in given sentence.
#
# **Sample Input:**
# Logic building is important
#
# **Sample Output:**
# 4
#
# **Explanation:**
# Split by spaces.

# %% [markdown]
# ### 48. Check Anagram Strings
#
# **Question:**
# Check if two strings are anagrams.
#
# **Sample Input:**
# listen silent
#
# **Sample Output:**
# Anagram
#
# **Explanation:**
# Same characters, different order.

# %% [markdown]
# ### 49. Reverse Words in Sentence
#
# **Question:**
# Reverse order of words in a sentence.
#
# **Sample Input:**
# I love code
#
# **Sample Output:**
# code love I
#
# **Explanation:**
# Split and reverse words.

# %% [markdown]
# ### 50. Replace Spaces with Special Character
#
# **Question:**
# Replace spaces with '@'.
#
# **Sample Input:**
# Hello World
#
# **Sample Output:**
# Hello@World
#
# **Explanation:**
# Use string replace logic.
