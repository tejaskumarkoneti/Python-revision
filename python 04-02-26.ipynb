# %% [markdown]
# ##  Count how many times a word appears in a sentence (without In Built Functions)

# %%
sentence = "Yesterday a turtle lived in India went to laundry found a secret key"

search_word = input("Enter the word to search in sentence ")

st = ""

li = []

for ch in sentence:
    
    if ch == " ":
        
        li += [st]
        st =""
        
    else:
        
        st += ch
        

count = 0
        
for item in li:
    
    if item == search_word:
        
        count +=1
        
print(count)
# Out:
# 2

# %% [markdown]
# ##  Find the largest number entered until the user types “stop”

# %%
larg = 0

while True:
    
    user = input("Enter the numbers (or Type Stop) : ")
    
    if user == "stop":
        
        break
    
    val = int(user)
    
    if larg == 0 or val > larg:
        
        larg = val
        
print("Largest number is {} ".format(larg))
# Out:
# Largest number is 6

# %% [markdown]
# # BASIC STRING PROBLEMS (Foundation)

# %% [markdown]
# ### 1. Find the length of a string without using len().

# %%
st = "Rajes"

count = 0

for iter in st:
    
    count +=1
    
print(count)
# Out:
# 5

# %% [markdown]
# ### 2. Count the number of vowels and consonants in a string.

# %%
st = "Rajesh"

vowels = ['a','e','i','o','u']

v_count = 0

c_count = 0

for ch in st:
    
    if ch in vowels:
        
        v_count +=1
        
    else:
        
        c_count +=1
        
print("No of vowels in {} are {}".format(st,v_count))

print("No of constants in {} are {}".format(st,c_count))
# Out:
# No of vowels in Rajesh are 2
# No of constants in Rajesh are 4

# %% [markdown]
# ### 3. Reverse a string.

# %%
st = "Rajesh"

for char in range(len(st)-1,-1,-1):
    
    print(st[char],end="")
# Out:
# hsejaR

# %% [markdown]
# ### 4. Check whether a string is a palindrome.

# %%
st1 = "mada"


rev = ""

for ch in range(len(st1)-1,-1,-1):
    
    rev = rev + st1[ch]

print(rev)
    
if rev == st1:
    
    print("Palindrome")

else:
    
    print("Not Palindrome")
# Out:
# adam
# Not Palindrome

# %% [markdown]
# ### 5. Count uppercase, lowercase, digits, and special characters.

# %% [markdown]
# ### 6. Convert all characters of a string to uppercase without using upper().

# %%
# ASCII Values

# A-Z (65 - 90)
# a - z (90 - 122)

# %%
st = "tejas"

res= ""

for ch in st:
    
    if ord(ch) >= ord("a") and ord(ch) <= ord("z"):
        
        res_int = ord(ch) - 32
        
        res += chr(res_int)
    
print(res)
# Out:
# TEJAS

# %% [markdown]
# ### 7. Replace spaces with underscores.

# %%
str1 = "tejas kumar"

str2 = ""

for index in range(len(str1)):
        
    if str1[index] == " ":
        
        str2[char] = "_"
    
    
    str2 += str2[char]
        
print(str2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 12
#       7     if str1[index] == " ":
#       9         str2[char] = "_"
# ---> 12     str2 += str2[char]
#      14 print(str2)
#
# IndexError: string index out of range

# %% [markdown]
# ### 8. Remove duplicate characters from a string.

# %%
stg = "madam"

lt = []

for index in range(len(stg)):
    
    ch = stg[index]
    
    if ch != " ":
        
        lt += [ch]
    
#print(lt)     

res = ""

for item in lt:
    
    if item not in res:
        
        res += item
        
print(res)
# Out:
# mad

# %% [markdown]
# ### 9. Count the frequency of each character.

# %%
s = "madam"

d = {}

for ch in s:
    
    if ch in d:
        
        d[ch] +=1
        
    else:
        
        d[ch] = 1
        
for k in d:
    
    print("{} = {}".format(k,d[k]))
# Out:
# m = 2
# a = 2
# d = 1

# %% [markdown]
# ### 10. Find the first non-repeating character.

# %%
s = "algebra"

d = {}

for ch in s:
    
    if ch in d:
        
        d[ch] += 1
        
    else:
        
        d[ch] = 1    
        
print(d)

# need to prnt first unique element in the string


for k,v in d.items():
    
    if v == 1:
        
        print("The first non-repeating character in {} is {}".format(s,k))
        
        break
# Out:
# {'a': 2, 'l': 1, 'g': 1, 'e': 1, 'b': 1, 'r': 1}
# The first non-repeating character in algebra is l

# %% [markdown]
# # INTERMEDIATE STRING PROBLEMS (Logic Building)

# %% [markdown]
# ### 11. Check whether two strings are anagrams.

# %% [markdown]
# ### 12. Find the most frequent character in a string.

# %% [markdown]
# ### 13. Check whether a string contains only digits (OTP validation).

# %% [markdown]
# ### 14. Capitalize the first letter of each word without using title().

# %% [markdown]
# ### 15. Count the number of words in a sentence.

# %% [markdown]
# ### 16. Reverse each word in a sentence.

# %% [markdown]
# ### 17. Find the longest word in a sentence.

# %% [markdown]
# ### 18. Remove all special characters from a string.

# %% [markdown]
# ### 19. Check whether a string starts and ends with given characters.

# %% [markdown]
# ### 20. Compress a string (example: aaabbc → a3b2c1).

# %% [markdown]
# # BONUS (Real-Time / Interview-Level Challenges)

# %% [markdown]
# ### • Validate email format using strings.

# %% [markdown]
# ### • Mask sensitive data (example: phone number → 98******12).

# %% [markdown]
# ### • Check password strength.

# %% [markdown]
# ### • Extract domain name from a URL.

# %% [markdown]
# ### • Find all substrings of a string.

# %% [markdown]
# ### • Rotate a string and check equality
