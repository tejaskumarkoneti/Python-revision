# %% [markdown]
# ### 51. First Non-Repeating Character
#
# **Question:**
# Find first character that does not repeat.
#
# **Sample Input:**
# success
#
# **Sample Output:**
# u
#
# **Explanation:**
# Check frequency of each character.

# %% [markdown]
# ### 52. Duplicate Characters in String
#
# **Question:**
# Identify duplicate characters.
#
# **Sample Input:**
# programming
#
# **Sample Output:**
# g r m
#
# **Explanation:**
# Characters appearing more than once.

# %% [markdown]
# ### 53. Stack Implementation Using Array
#
# **Question:**
# Implement push and pop operations.
#
# **Sample Input:**
# Push 10, Push 20, Pop
#
# **Sample Output:**
# 20 removed
#
# **Explanation:**
# Follow LIFO principle.

# %% [markdown]
# ### 54. Queue Using Array
#
# **Question:**
# Implement enqueue and dequeue operations.
#
# **Sample Input:**
# Enqueue 5, Enqueue 10, Dequeue
#
# **Sample Output:**
# 5 removed
#
# **Explanation:**
# Follow FIFO principle.

# %% [markdown]
# ### 55. Validate Parentheses
#
# **Question:**
# Check if parentheses are balanced.
#
# **Sample Input:**
# {[()]}
#
# **Sample Output:**
# Valid
#
# **Explanation:**
# Use stack to match pairs.

# %% [markdown]
# ### 56. Decimal to Binary Conversion
#
# **Question:**
# Convert decimal number to binary.
#
# **Sample Input:**
# 10
#
# **Sample Output:**
# 1010
#
# **Explanation:**
# Divide by 2 repeatedly.

# %% [markdown]
# ### 57. Binary to Decimal Conversion
#
# **Question:**
# Convert binary to decimal.
#
# **Sample Input:**
# 1010
#
# **Sample Output:**
# 10
#
# **Explanation:**
# Multiply bits with 2^position.

# %% [markdown]
# ### 58. Armstrong Number
#
# **Question:**
# Check if number is Armstrong.
#
# **Sample Input:**
# 153
#
# **Sample Output:**
# Armstrong
#
# **Explanation:**
# 1³ + 5³ + 3³ = 153

# %% [markdown]
# ### 59. Happy Number
#
# **Question:**
# Check if number ends in 1 by sum of square of digits.
#
# **Sample Input:**
# 19
#
# **Sample Output:**
# Happy Number
#
# **Explanation:**
# Repeats until 1 or loop detected.

# %% [markdown]
# ### 60. Strong Number
#
# **Question:**
# Check if sum of factorial of digits equals number.
#
# **Sample Input:**
# 145
#
# **Sample Output:**
# Strong Number
#
# **Explanation:**
# 1! + 4! + 5! = 145
