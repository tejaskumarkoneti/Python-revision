# %% [markdown]
# ### 71. Number Guessing Game
# **Sample Input:** User guesses: 50, 75, 60 (Target: 60)
# **Sample Output:** Correct Guess
# **Explanation:** User keeps guessing until number matches.

# %% [markdown]
# ### 72. Sudoku Solution Validator
# **Sample Input:** 9x9 Sudoku Grid
# **Sample Output:** Valid Sudoku
# **Explanation:** Each row, column, subgrid must contain 1–9.

# %% [markdown]
# ### 73. Tic Tac Toe Winner Detection
# **Sample Input:** Board with 3 X in a row
# **Sample Output:** Player X Wins
# **Explanation:** Check rows, columns, diagonals.

# %% [markdown]
# ### 74. Generate All Permutations of a String
# **Sample Input:** ABC
# **Sample Output:** ABC, ACB, BAC, BCA, CAB, CBA
# **Explanation:** Arrange characters in all orders.

# %% [markdown]
# ### 75. Generate All Subsets of a Set
# **Sample Input:** {1,2}
# **Sample Output:** {}, {1}, {2}, {1,2}
# **Explanation:** Power set generation.

# %% [markdown]
# ### 76. Optimized Fibonacci Using Memoization
# **Sample Input:** 7
# **Sample Output:** 13
# **Explanation:** Store previous results to optimize recursion.

# %% [markdown]
# ### 77. Tower of Hanoi Problem
# **Sample Input:** 3 disks
# **Sample Output:** 7 moves
# **Explanation:** Move disks using recursion rules.

# %% [markdown]
# ### 78. Maze Solver Using Backtracking
# **Sample Input:** Grid maze
# **Sample Output:** Path Found
# **Explanation:** Explore paths recursively.

# %% [markdown]
# ### 79. Shortest Path in Matrix
# **Sample Input:** Matrix with obstacles
# **Sample Output:** Minimum steps = X
# **Explanation:** Use BFS / Dijkstra.

# %% [markdown]
# ### 80. Implement Linked List
# **Sample Input:** Insert 10,20,30
# **Sample Output:** 10→20→30
# **Explanation:** Nodes connected via pointers.

# %% [markdown]
# ### 81. Reverse Linked List
# **Sample Input:** 1→2→3
# **Sample Output:** 3→2→1
# **Explanation:** Reverse links.

# %% [markdown]
# ### 82. Detect Loop in Linked List
# **Sample Input:** Tail connects to node 2
# **Sample Output:** Loop Detected
# **Explanation:** Floyd cycle detection.

# %% [markdown]
# ### 83. Quick Sort Algorithm
# **Sample Input:** 5 3 8 1
# **Sample Output:** 1 3 5 8
# **Explanation:** Divide & pivot partition.

# %% [markdown]
# ### 84. Merge Sort Algorithm
# **Sample Input:** 9 4 7 2
# **Sample Output:** 2 4 7 9
# **Explanation:** Divide & merge sorted halves.

# %% [markdown]
# ### 85. Implement Binary Tree
# **Sample Input:** Insert nodes
# **Sample Output:** Tree Structure
# **Explanation:** Parent-child hierarchy.

# %% [markdown]
# ### 86. Binary Search Tree Operations
# **Sample Input:** Insert 5,3,7
# **Sample Output:** Inorder: 3 5 7
# **Explanation:** Left < Root < Right.

# %% [markdown]
# ### 87. Level Order Traversal
# **Sample Input:** Binary Tree
# **Sample Output:** Nodes level by level
# **Explanation:** BFS traversal.

# %% [markdown]
# ### 88. Depth First Search (DFS)
# **Sample Input:** Graph nodes
# **Sample Output:** DFS Order
# **Explanation:** Explore depth-wise.

# %% [markdown]
# ### 89. Breadth First Search (BFS)
# **Sample Input:** Graph nodes
# **Sample Output:** BFS Order
# **Explanation:** Explore level-wise.

# %% [markdown]
# ### 90. Dijkstra’s Algorithm
# **Sample Input:** Weighted graph
# **Sample Output:** Shortest distance
# **Explanation:** Greedy path optimization.

# %% [markdown]
# ### 91. Chatbot Basic Response Logic
# **Sample Input:** “Hi”
# **Sample Output:** “Hello User”
# **Explanation:** Rule-based replies.

# %% [markdown]
# ### 92. Recommendation System Logic
# **Sample Input:** User likes Action movies
# **Sample Output:** Recommend similar movies
# **Explanation:** Preference filtering.

# %% [markdown]
# ### 93. Online Voting System
# **Sample Input:** Vote for Candidate A
# **Sample Output:** Vote Count Updated
# **Explanation:** Secure vote storage.

# %% [markdown]
# ### 94. Railway Reservation System
# **Sample Input:** Book Seat
# **Sample Output:** Ticket Confirmed
# **Explanation:** Check availability.

# %% [markdown]
# ### 95. Hostel Management System
# **Sample Input:** Student Check‑in
# **Sample Output:** Room Allocated
# **Explanation:** Manage rooms.

# %% [markdown]
# ### 96. Expense Tracker System
# **Sample Input:** Add Expense 500
# **Sample Output:** Total Updated
# **Explanation:** Track spending.

# %% [markdown]
# ### 97. Library Management System
# **Sample Input:** Issue Book
# **Sample Output:** Book Issued
# **Explanation:** Track inventory.

# %% [markdown]
# ### 98. Online Shopping Cart System
# **Sample Input:** Add Item
# **Sample Output:** Cart Updated
# **Explanation:** Maintain cart list.

# %% [markdown]
# ### 99. Multi‑User Role‑Based Login System
# **Sample Input:** Admin Login
# **Sample Output:** Admin Dashboard
# **Explanation:** Role authentication.

# %% [markdown]
# ### 100. Real‑Time Traffic Light Control System
# **Sample Input:** Vehicle Density High
# **Sample Output:** Green Signal Extended
# **Explanation:** Adaptive signal timing.
