# %% [markdown]
# Check whether a number is prime (updated version)

# %%
def prime(n): # function defination
    if n <= 1:
        return True
    i = 2
    while i < n:
        count = 0
        if n % i == 0:
            return False
        i+=1
    
    return True
n = 5
is_Prime = prime(n)

if is_Prime:
    print("Prime number")
else:
    print("Not prime number")
# Out:
# Prime number
