# %% [markdown]
# ### 1. Create a tuple with 5 integers and print it

# %% [markdown]
# ### 2. Access the first and last element of a tuple

# %% [markdown]
# ### 3. Create a single-element tuple

# %% [markdown]
# ### 4. Find length of a tuple

# %% [markdown]
# ### 5. Count how many times 5 appears in (5, 1, 5, 2, 5)

# %% [markdown]
# ### 6. Slice a tuple to get middle elements

# %% [markdown]
# ### 7. Find maximum and minimum values in a tuple

# %% [markdown]
# ### 8. Convert a list into a tuple

# %% [markdown]
# ### 9. Add two tuples

# %% [markdown]
# ### 10. Check if an element exists in a tuple

# %% [markdown]
# ### 11. Swap two numbers using tuple unpacking

# %% [markdown]
# ### 12. Store student details (id, name, marks) in a tuple

# %% [markdown]
# ### 13. Print only even numbers from a tuple

# %% [markdown]
# ### 14. Reverse a tuple

# %% [markdown]
# ### 15. Find sum of all elements in a tuple

# %% [markdown]
# ### 16. Remove duplicates from a tuple

# %% [markdown]
# ### 17. Convert tuple of strings to uppercase

# %% [markdown]
# ### 18. Find second largest number in a tuple

# %% [markdown]
# ### 19. Check whether tuple is palindrome

# %% [markdown]
# ### 20. Convert nested tuple into list
