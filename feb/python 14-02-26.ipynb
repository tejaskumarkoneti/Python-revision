# %% [markdown]
# ### 11. Multiplication Table
#
# **Question:**
# Print multiplication table of a number up to 10.
#
# **Sample Input:**
# 3
#
# **Sample Output:**
# 3x1=3
# 3x2=6
# ...
# 3x10=30
#
# **Explanation:**
# Multiply 3 with numbers 1–10.

# %% [markdown]
# ### 12. Sum of First N Natural Numbers
#
# **Question:**
# Find sum of first N natural numbers.
#
# **Sample Input:**
# 10
#
# **Sample Output:**
# 55
#
# **Explanation:**
# Use formula N(N+1)/2.

# %% [markdown]
# ### 13. Square and Cube
#
# **Question:**
# Print square and cube of given number.
#
# **Sample Input:**
# 4
#
# **Sample Output:**
# Square:16 Cube:64
#
# **Explanation:**
# 4² and 4³.

# %% [markdown]
# ### 14. Swap Without Third Variable
#
# **Question:**
# Swap two numbers without using temp variable.
#
# **Sample Input:**
# A=5 B=10
#
# **Sample Output:**
# A=10 B=5
#
# **Explanation:**
# Use arithmetic or XOR logic.

# %% [markdown]
# ### 15. Vowel or Consonant
#
# **Question:**
# Check whether a character is vowel or consonant.
#
# **Sample Input:**
# a
#
# **Sample Output:**
# Vowel
#
# **Explanation:**
# Vowels: a e i o u

# %% [markdown]
# ### 16. Simple Calculator
#
# **Question:**
# Perform +, -, *, / operations on two numbers.
#
# **Sample Input:**
# 10 5 *
#
# **Sample Output:**
# 50
#
# **Explanation:**
# Apply operator accordingly.

# %% [markdown]
# ### 17. Minimum of 5 Numbers
#
# **Question:**
# Find smallest number among five inputs.
#
# **Sample Input:**
# 5 2 8 1 9
#
# **Sample Output:**
# 1
#
# **Explanation:**
# Compare all values.

# %% [markdown]
# ### 18. Star Triangle Pattern
#
# **Question:**
# Print left aligned triangle of stars.
#
# **Sample Input:**
# 4
#
# **Sample Output:**
# *
# **
# ***
# ****
#
# **Explanation:**
# Stars increase each row.

# %% [markdown]
# ### 19. Sum of Even Numbers 1 to N
#
# **Question:**
# Calculate sum of even numbers till N.
#
# **Sample Input:**
# 10
#
# **Sample Output:**
# 30
#
# **Explanation:**
# 2+4+6+8+10

# %% [markdown]
# ### 20. Count Even and Odd in List
#
# **Question:**
# Given list, count even and odd numbers.
#
# **Sample Input:**
# 1 2 3 4 5 6
#
# **Sample Output:**
# Even:3 Odd:3
#
# **Explanation:**
# Separate by divisor 2.
