# %% [markdown]
# ##  Keep asking the user to enter a password until it is correct

# %%
password=""

while password != "admin":
    password = input("enter the correct password :")

print("Login Succesfull")
# Out:
# Login Succesfull

# %% [markdown]
# ##  Keep asking the user to enter a number until it is positive

# %%
number = int(input("enter a number :"))

while number <= 0:
    number = int(input("Enter the positive number"))

print("Number is positive ",number)
# Out:
# Number is positive  6
